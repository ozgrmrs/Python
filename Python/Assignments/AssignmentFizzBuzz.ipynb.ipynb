# %% [markdown]
# **Fizz Buzzz Numbers **

# %%
x = list(range(1,101))
for i in x :
  if i % 3 == 0:
    if i % (3*5) == 0 :
      print("FizzBuzz")
    else :
      print("Fizz")
  elif i % 5== 0 :
    print("Buzz")
  else :
    print(i
